# %% [markdown]
# # Zero-Cost Proxy Evaluation  w/ minibatch
#
# Testing zero-cost proxies with zone-agnostic behavior policy model

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
import pandas as pd
import pickle
sys.path.insert(0, "../")
import torch
from ppo import PPO
import glob
from tqdm.notebook import tqdm
import json
from scipy.stats import spearmanr

# %%
log_data = pd.read_csv("../data/rule_based_log_data/15zone/0_cleaned_log.csv")
with open("../data/rule_based_log_data/15zone/action_probs_all_data.pkl", "rb") as f:
    behavior_model = pickle.load(f)
# with open("../data/invalid_policy_list_20220705.json") as f:
#     invalid_policies = json.load(f)["invalid_policies"]
invalid_policies = []

# %% [markdown]
# ## 30 Day MiniBatch

# %%
num_ts_per_day = 4 * 24
num_days = 15
ts_end = num_ts_per_day * num_days
zones = log_data["zone"].unique()

# %% [markdown]
# ## Loading all Policies

# %%
policy_list = sorted(list(glob.glob(f"../policy_library_20220820/**.pth")))

# %% [markdown]
# ### 1. GradNorm

# %%
from zero_cost_proxies.grad_norm import GradNorm
policy_scores = {}
for zone in zones:
    print(zone)
    ope_data = log_data[log_data["zone"] == zone].sort_values(by=["timestep"])
    ope_data = log_data[:ts_end]
    for policy in tqdm(policy_list):
        agent = PPO(6, 1, 0.003, 0.0005, 1, 10, 0.2,
                    has_continuous_action_space=True, action_std_init=0.2, 
                    device=torch.device('cpu'), diverse_policies=list(),
                    diverse_weight=0, diverse_increase=True)
        agent.load(policy)
        agent.policy_evaluation = True
        agent.policy_old.set_action_std(0.1)
        gn = GradNorm(agent, behavior_model)
        if policy not in invalid_policies:
            norm = gn.get_grad_norm(ope_data)
        else:
            continue
        if policy not in policy_scores:
            policy_scores[policy] = {}
        if zone not in policy_scores[policy]:
            policy_scores[policy][zone] = norm
# Out:
# Perimeter_top_ZN_3
#   0%|          | 0/800 [00:00<?, ?it/s]
# /Users/aakashsasikumar/Documents/MSc/Research/Dissimilar Policy/building-MARL/studies/../ope/iw.py:61: RuntimeWarning: divide by zero encountered in log
#   return np.log(value / (1- value))
# Perimeter_bot_ZN_1
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_top_ZN_1
#   0%|          | 0/800 [00:00<?, ?it/s]
# Core_bottom
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_top_ZN_4
#   0%|          | 0/800 [00:00<?, ?it/s]
# Core_top
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_2
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_3
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_4
#   0%|          | 0/800 [00:00<?, ?it/s]
# Core_mid
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_2
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_3
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_top_ZN_2
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_1
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_4
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
eval_data_loc = "../data/evaluation_report_20220820.csv"
df = pd.read_csv(eval_data_loc, header=None, names=["datetime","policy","zone","energy"])
spearman_corr = {}
for zone in zones:
    eval_df = df[df["zone"] == zone]

    # invalid_policies = list(set(policy_list) - set(policy_scores.keys()))
    for i_policy in invalid_policies:
        eval_df = eval_df[eval_df["policy"]!=i_policy[3:]]
    eval_df = eval_df.sort_values(by=["energy"])
    score_list = []
    for i, row in eval_df.iterrows():
        score_list.append(policy_scores[f"../{row['policy']}"][zone])

    eval_df["ope_scores"] = score_list
    correlation = spearmanr(eval_df["energy"].values, eval_df["ope_scores"].values)
    spearman_corr[zone] = correlation

# %%
policy_scores
# Out:
# {'../policy_library/100_0.pth': {'Perimeter_top_ZN_3': 0.014098737388849258,
#   'Perimeter_bot_ZN_1': 0.014098737388849258,
#   'Perimeter_top_ZN_1': 0.014098737388849258,
#   'Core_bottom': 0.014098737388849258,
#   'Perimeter_top_ZN_4': 0.014098737388849258,
#   'Core_top': 0.014098737388849258,
#   'Perimeter_bot_ZN_2': 0.014098737388849258,
#   'Perimeter_bot_ZN_3': 0.014098737388849258,
#   'Perimeter_mid_ZN_4': 0.014098737388849258,
#   'Core_mid': 0.014098737388849258,
#   'Perimeter_mid_ZN_2': 0.014098737388849258,
#   'Perimeter_mid_ZN_3': 0.014098737388849258,
#   'Perimeter_top_ZN_2': 0.014098737388849258,
#   'Perimeter_mid_ZN_1': 0.014098737388849258,
#   'Perimeter_bot_ZN_4': 0.014098737388849258},
#  '../policy_library/100_0_blind.pth': {'Perimeter_top_ZN_3': 1.3776978254318237,
#   'Perimeter_bot_ZN_1': 1.3776978254318237,
#   'Perimeter_top_ZN_1': 1.3776978254318237,
#   'Core_bottom': 1.3776978254318237,
#   'Perimeter_top_ZN_4': 1.3776978254318237,
#   'Core_top': 1.3776978254318237,
#   'Perimeter_bot_ZN_2': 1.3776978254318237,
#   'Perimeter_bot_ZN_3': 1.3776978254318237,
#   'Perimeter_mid_ZN_4': 1.3776978254318237,
#   'Core_mid': 1.3776978254318237,
#   'Perimeter_mid_ZN_2': 1.3776978254318237,
#   'Perimeter_mid_ZN_3': 1.3776978254318237,
#   'Perimeter_top_ZN_2': 1.3776978254318237,
#   'Perimeter_mid_ZN_1': 1.3776978254318237,
#   'Perimeter_bot_ZN_4': 1.3776978254318237},
#  '../policy_library/100_1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_1_1e-1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_1_1e0.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_1_1e1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_1_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_2.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_2_1e-1_blind.pth': {'Perimeter_top_ZN_3': 0.05488673597574234,
#   'Perimeter_bot_ZN_1': 0.05488673597574234,
#   'Perimeter_top_ZN_1': 0.05488673597574234,
#   'Core_bottom': 0.05488673597574234,
#   'Perimeter_top_ZN_4': 0.05488673597574234,
#   'Core_top': 0.05488673597574234,
#   'Perimeter_bot_ZN_2': 0.05488673597574234,
#   'Perimeter_bot_ZN_3': 0.05488673597574234,
#   'Perimeter_mid_ZN_4': 0.05488673597574234,
#   'Core_mid': 0.05488673597574234,
#   'Perimeter_mid_ZN_2': 0.05488673597574234,
#   'Perimeter_mid_ZN_3': 0.05488673597574234,
#   'Perimeter_top_ZN_2': 0.05488673597574234,
#   'Perimeter_mid_ZN_1': 0.05488673597574234,
#   'Perimeter_bot_ZN_4': 0.05488673597574234},
#  '../policy_library/100_2_1e1_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_2_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_3.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_3_blind.pth': {'Perimeter_top_ZN_3': 0.6805421113967896,
#   'Perimeter_bot_ZN_1': 0.6805421113967896,
#   'Perimeter_top_ZN_1': 0.6805421113967896,
#   'Core_bottom': 0.6805421113967896,
#   'Perimeter_top_ZN_4': 0.6805421113967896,
#   'Core_top': 0.6805421113967896,
#   'Perimeter_bot_ZN_2': 0.6805421113967896,
#   'Perimeter_bot_ZN_3': 0.6805421113967896,
#   'Perimeter_mid_ZN_4': 0.6805421113967896,
#   'Core_mid': 0.6805421113967896,
#   'Perimeter_mid_ZN_2': 0.6805421113967896,
#   'Perimeter_mid_ZN_3': 0.6805421113967896,
#   'Perimeter_top_ZN_2': 0.6805421113967896,
#   'Perimeter_mid_ZN_1': 0.6805421113967896,
#   'Perimeter_bot_ZN_4': 0.6805421113967896},
#  '../policy_library/100_4.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/100_4_1e0.pth': {'Perimeter_top_ZN_3': 26.012447357177734,
#   'Perimeter_bot_ZN_1': 26.012447357177734,
#   'Perimeter_top_ZN_1': 26.012447357177734,
#   'Core_bottom': 26.012447357177734,
#   'Perimeter_top_ZN_4': 26.012447357177734,
#   'Core_top': 26.012447357177734,
#   'Perimeter_bot_ZN_2': 26.012447357177734,
#   'Perimeter_bot_ZN_3': 26.012447357177734,
#   'Perimeter_mid_ZN_4': 26.012447357177734,
#   'Core_mid': 26.012447357177734,
#   'Perimeter_mid_ZN_2': 26.012447357177734,
#   'Perimeter_mid_ZN_3': 26.012447357177734,
#   'Perimeter_top_ZN_2': 26.012447357177734,
#   'Perimeter_mid_ZN_1': 26.012447357177734,
#   'Perimeter_bot_ZN_4': 26.012447357177734},
#  '../policy_library/100_4_1e1.pth': {'Perimeter_top_ZN_3': 8.963894844055176,
#   'Perimeter_bot_ZN_1': 8.963894844055176,
#   'Perimeter_top_ZN_1': 8.963894844055176,
#   'Core_bottom': 8.963894844055176,
#   'Perimeter_top_ZN_4': 8.963894844055176,
#   'Core_top': 8.963894844055176,
#   'Perimeter_bot_ZN_2': 8.963894844055176,
#   'Perimeter_bot_ZN_3': 8.963894844055176,
#   'Perimeter_mid_ZN_4': 8.963894844055176,
#   'Core_mid': 8.963894844055176,
#   'Perimeter_mid_ZN_2': 8.963894844055176,
#   'Perimeter_mid_ZN_3': 8.963894844055176,
#   'Perimeter_top_ZN_2': 8.963894844055176,
#   'Perimeter_mid_ZN_1': 8.963894844055176,
#   'Perimeter_bot_ZN_4': 8.963894844055176},
#  '../policy_library/100_4_blind.pth': {'Perimeter_top_ZN_3': 1.0240345001220703,
#   'Perimeter_bot_ZN_1': 1.0240345001220703,
#   'Perimeter_top_ZN_1': 1.0240345001220703,
#   'Core_bottom': 1.0240345001220703,
#   'Perimeter_top_ZN_4': 1.0240345001220703,
#   'Core_top': 1.0240345001220703,
#   'Perimeter_bot_ZN_2': 1.0240345001220703,
#   'Perimeter_bot_ZN_3': 1.0240345001220703,
#   'Perimeter_mid_ZN_4': 1.0240345001220703,
#   'Core_mid': 1.0240345001220703,
#   'Perimeter_mid_ZN_2': 1.0240345001220703,
#   'Perimeter_mid_ZN_3': 1.0240345001220703,
#   'Perimeter_top_ZN_2': 1.0240345001220703,
#   'Perimeter_mid_ZN_1': 1.0240345001220703,
#   'Perimeter_bot_ZN_4': 1.0240345001220703},
#  '../policy_library/101_0.pth': {'Perimeter_top_ZN_3': 4.71014928817749,
#   'Perimeter_bot_ZN_1': 4.71014928817749,
#   'Perimeter_top_ZN_1': 4.71014928817749,
#   'Core_bottom': 4.71014928817749,
#   'Perimeter_top_ZN_4': 4.71014928817749,
#   'Core_top': 4.71014928817749,
#   'Perimeter_bot_ZN_2': 4.71014928817749,
#   'Perimeter_bot_ZN_3': 4.71014928817749,
#   'Perimeter_mid_ZN_4': 4.71014928817749,
#   'Core_mid': 4.71014928817749,
#   'Perimeter_mid_ZN_2': 4.71014928817749,
#   'Perimeter_mid_ZN_3': 4.71014928817749,
#   'Perimeter_top_ZN_2': 4.71014928817749,
#   'Perimeter_mid_ZN_1': 4.71014928817749,
#   'Perimeter_bot_ZN_4': 4.71014928817749},
#  '../policy_library/101_0_1e-1_blind.pth': {'Perimeter_top_ZN_3': 1.9391133785247803,
#   'Perimeter_bot_ZN_1': 1.9391133785247803,
#   'Perimeter_top_ZN_1': 1.9391133785247803,
#   'Core_bottom': 1.9391133785247803,
#   'Perimeter_top_ZN_4': 1.9391133785247803,
#   'Core_top': 1.9391133785247803,
#   'Perimeter_bot_ZN_2': 1.9391133785247803,
#   'Perimeter_bot_ZN_3': 1.9391133785247803,
#   'Perimeter_mid_ZN_4': 1.9391133785247803,
#   'Core_mid': 1.9391133785247803,
#   'Perimeter_mid_ZN_2': 1.9391133785247803,
#   'Perimeter_mid_ZN_3': 1.9391133785247803,
#   'Perimeter_top_ZN_2': 1.9391133785247803,
#   'Perimeter_mid_ZN_1': 1.9391133785247803,
#   'Perimeter_bot_ZN_4': 1.9391133785247803},
#  '../policy_library/101_0_1e0_blind.pth': {'Perimeter_top_ZN_3': 1.9391133785247803,
#   'Perimeter_bot_ZN_1': 1.9391133785247803,
#   'Perimeter_top_ZN_1': 1.9391133785247803,
#   'Core_bottom': 1.9391133785247803,
#   'Perimeter_top_ZN_4': 1.9391133785247803,
#   'Core_top': 1.9391133785247803,
#   'Perimeter_bot_ZN_2': 1.9391133785247803,
#   'Perimeter_bot_ZN_3': 1.9391133785247803,
#   'Perimeter_mid_ZN_4': 1.9391133785247803,
#   'Core_mid': 1.9391133785247803,
#   'Perimeter_mid_ZN_2': 1.9391133785247803,
#   'Perimeter_mid_ZN_3': 1.9391133785247803,
#   'Perimeter_top_ZN_2': 1.9391133785247803,
#   'Perimeter_mid_ZN_1': 1.9391133785247803,
#   'Perimeter_bot_ZN_4': 1.9391133785247803},
#  '../policy_library/101_0_blind.pth': {'Perimeter_top_ZN_3': 0.06412447988986969,
#   'Perimeter_bot_ZN_1': 0.06412447988986969,
#   'Perimeter_top_ZN_1': 0.06412447988986969,
#   'Core_bottom': 0.06412447988986969,
#   'Perimeter_top_ZN_4': 0.06412447988986969,
#   'Core_top': 0.06412447988986969,
#   'Perimeter_bot_ZN_2': 0.06412447988986969,
#   'Perimeter_bot_ZN_3': 0.06412447988986969,
#   'Perimeter_mid_ZN_4': 0.06412447988986969,
#   'Core_mid': 0.06412447988986969,
#   'Perimeter_mid_ZN_2': 0.06412447988986969,
#   'Perimeter_mid_ZN_3': 0.06412447988986969,
#   'Perimeter_top_ZN_2': 0.06412447988986969,
#   'Perimeter_mid_ZN_1': 0.06412447988986969,
#   'Perimeter_bot_ZN_4': 0.06412447988986969},
#  '../policy_library/101_1.pth': {'Perimeter_top_ZN_3': 1.3307678699493408,
#   'Perimeter_bot_ZN_1': 1.3307678699493408,
#   'Perimeter_top_ZN_1': 1.3307678699493408,
#   'Core_bottom': 1.3307678699493408,
#   'Perimeter_top_ZN_4': 1.3307678699493408,
#   'Core_top': 1.3307678699493408,
#   'Perimeter_bot_ZN_2': 1.3307678699493408,
#   'Perimeter_bot_ZN_3': 1.3307678699493408,
#   'Perimeter_mid_ZN_4': 1.3307678699493408,
#   'Core_mid': 1.3307678699493408,
#   'Perimeter_mid_ZN_2': 1.3307678699493408,
#   'Perimeter_mid_ZN_3': 1.3307678699493408,
#   'Perimeter_top_ZN_2': 1.3307678699493408,
#   'Perimeter_mid_ZN_1': 1.3307678699493408,
#   'Perimeter_bot_ZN_4': 1.3307678699493408},
#  '../policy_library/101_1_1e-1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/101_1_1e-1_blind.pth': {'Perimeter_top_ZN_3': 2.3570839724484927e-11,
#   'Perimeter_bot_ZN_1': 2.3570839724484927e-11,
#   'Perimeter_top_ZN_1': 2.3570839724484927e-11,
#   'Core_bottom': 2.3570839724484927e-11,
#   'Perimeter_top_ZN_4': 2.3570839724484927e-11,
#   'Core_top': 2.3570839724484927e-11,
#   'Perimeter_bot_ZN_2': 2.3570839724484927e-11,
#   'Perimeter_bot_ZN_3': 2.3570839724484927e-11,
#   'Perimeter_mid_ZN_4': 2.3570839724484927e-11,
#   'Core_mid': 2.3570839724484927e-11,
#   'Perimeter_mid_ZN_2': 2.3570839724484927e-11,
#   'Perimeter_mid_ZN_3': 2.3570839724484927e-11,
#   'Perimeter_top_ZN_2': 2.3570839724484927e-11,
#   'Perimeter_mid_ZN_1': 2.3570839724484927e-11,
#   'Perimeter_bot_ZN_4': 2.3570839724484927e-11},
#  '../policy_library/101_1_1e0_blind.pth': {'Perimeter_top_ZN_3': 2.3570839724484927e-11,
#   'Perimeter_bot_ZN_1': 2.3570839724484927e-11,
#   'Perimeter_top_ZN_1': 2.3570839724484927e-11,
#   'Core_bottom': 2.3570839724484927e-11,
#   'Perimeter_top_ZN_4': 2.3570839724484927e-11,
#   'Core_top': 2.3570839724484927e-11,
#   'Perimeter_bot_ZN_2': 2.3570839724484927e-11,
#   'Perimeter_bot_ZN_3': 2.3570839724484927e-11,
#   'Perimeter_mid_ZN_4': 2.3570839724484927e-11,
#   'Core_mid': 2.3570839724484927e-11,
#   'Perimeter_mid_ZN_2': 2.3570839724484927e-11,
#   'Perimeter_mid_ZN_3': 2.3570839724484927e-11,
#   'Perimeter_top_ZN_2': 2.3570839724484927e-11,
#   'Perimeter_mid_ZN_1': 2.3570839724484927e-11,
#   'Perimeter_bot_ZN_4': 2.3570839724484927e-11},
#  '../policy_library/101_1_1e1_blind.pth': {'Perimeter_top_ZN_3': 0.549382209777832,
#   'Perimeter_bot_ZN_1': 0.549382209777832,
#   'Perimeter_top_ZN_1': 0.549382209777832,
#   'Core_bottom': 0.549382209777832,
#   'Perimeter_top_ZN_4': 0.549382209777832,
#   'Core_top': 0.549382209777832,
#   'Perimeter_bot_ZN_2': 0.549382209777832,
#   'Perimeter_bot_ZN_3': 0.549382209777832,
#   'Perimeter_mid_ZN_4': 0.549382209777832,
#   'Core_mid': 0.549382209777832,
#   'Perimeter_mid_ZN_2': 0.549382209777832,
#   'Perimeter_mid_ZN_3': 0.549382209777832,
#   'Perimeter_top_ZN_2': 0.549382209777832,
#   'Perimeter_mid_ZN_1': 0.549382209777832,
#   'Perimeter_bot_ZN_4': 0.549382209777832},
#  '../policy_library/101_1_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/101_2.pth': {'Perimeter_top_ZN_3': 0.0005813102470710874,
#   'Perimeter_bot_ZN_1': 0.0005813102470710874,
#   'Perimeter_top_ZN_1': 0.0005813102470710874,
#   'Core_bottom': 0.0005813102470710874,
#   'Perimeter_top_ZN_4': 0.0005813102470710874,
#   'Core_top': 0.0005813102470710874,
#   'Perimeter_bot_ZN_2': 0.0005813102470710874,
#   'Perimeter_bot_ZN_3': 0.0005813102470710874,
#   'Perimeter_mid_ZN_4': 0.0005813102470710874,
#   'Core_mid': 0.0005813102470710874,
#   'Perimeter_mid_ZN_2': 0.0005813102470710874,
#   'Perimeter_mid_ZN_3': 0.0005813102470710874,
#   'Perimeter_top_ZN_2': 0.0005813102470710874,
#   'Perimeter_mid_ZN_1': 0.0005813102470710874,
#   'Perimeter_bot_ZN_4': 0.0005813102470710874},
#  '../policy_library/101_2_1e-1.pth': {'Perimeter_top_ZN_3': 5.997012138366699,
#   'Perimeter_bot_ZN_1': 5.997012138366699,
#   'Perimeter_top_ZN_1': 5.997012138366699,
#   'Core_bottom': 5.997012138366699,
#   'Perimeter_top_ZN_4': 5.997012138366699,
#   'Core_top': 5.997012138366699,
#   'Perimeter_bot_ZN_2': 5.997012138366699,
#   'Perimeter_bot_ZN_3': 5.997012138366699,
#   'Perimeter_mid_ZN_4': 5.997012138366699,
#   'Core_mid': 5.997012138366699,
#   'Perimeter_mid_ZN_2': 5.997012138366699,
#   'Perimeter_mid_ZN_3': 5.997012138366699,
#   'Perimeter_top_ZN_2': 5.997012138366699,
#   'Perimeter_mid_ZN_1': 5.997012138366699,
#   'Perimeter_bot_ZN_4': 5.997012138366699},
#  '../policy_library/101_2_1e-1_blind.pth': {'Perimeter_top_ZN_3': 0.000216866988921538,
#   'Perimeter_bot_ZN_1': 0.000216866988921538,
#   'Perimeter_top_ZN_1': 0.000216866988921538,
#   'Core_bottom': 0.000216866988921538,
#   'Perimeter_top_ZN_4': 0.000216866988921538,
#   'Core_top': 0.000216866988921538,
#   'Perimeter_bot_ZN_2': 0.000216866988921538,
#   'Perimeter_bot_ZN_3': 0.000216866988921538,
#   'Perimeter_mid_ZN_4': 0.000216866988921538,
#   'Core_mid': 0.000216866988921538,
#   'Perimeter_mid_ZN_2': 0.000216866988921538,
#   'Perimeter_mid_ZN_3': 0.000216866988921538,
#   'Perimeter_top_ZN_2': 0.000216866988921538,
#   'Perimeter_mid_ZN_1': 0.000216866988921538,
#   'Perimeter_bot_ZN_4': 0.000216866988921538},
#  '../policy_library/101_2_1e0_blind.pth': {'Perimeter_top_ZN_3': 0.000216866988921538,
#   'Perimeter_bot_ZN_1': 0.000216866988921538,
#   'Perimeter_top_ZN_1': 0.000216866988921538,
#   'Core_bottom': 0.000216866988921538,
#   'Perimeter_top_ZN_4': 0.000216866988921538,
#   'Core_top': 0.000216866988921538,
#   'Perimeter_bot_ZN_2': 0.000216866988921538,
#   'Perimeter_bot_ZN_3': 0.000216866988921538,
#   'Perimeter_mid_ZN_4': 0.000216866988921538,
#   'Core_mid': 0.000216866988921538,
#   'Perimeter_mid_ZN_2': 0.000216866988921538,
#   'Perimeter_mid_ZN_3': 0.000216866988921538,
#   'Perimeter_top_ZN_2': 0.000216866988921538,
#   'Perimeter_mid_ZN_1': 0.000216866988921538,
#   'Perimeter_bot_ZN_4': 0.000216866988921538},
#  '../policy_library/101_2_blind.pth': {'Perimeter_top_ZN_3': 0.1401161253452301,
#   'Perimeter_bot_ZN_1': 0.1401161253452301,
#   'Perimeter_top_ZN_1': 0.1401161253452301,
#   'Core_bottom': 0.1401161253452301,
#   'Perimeter_top_ZN_4': 0.1401161253452301,
#   'Core_top': 0.1401161253452301,
#   'Perimeter_bot_ZN_2': 0.1401161253452301,
#   'Perimeter_bot_ZN_3': 0.1401161253452301,
#   'Perimeter_mid_ZN_4': 0.1401161253452301,
#   'Core_mid': 0.1401161253452301,
#   'Perimeter_mid_ZN_2': 0.1401161253452301,
#   'Perimeter_mid_ZN_3': 0.1401161253452301,
#   'Perimeter_top_ZN_2': 0.1401161253452301,
#   'Perimeter_mid_ZN_1': 0.1401161253452301,
#   'Perimeter_bot_ZN_4': 0.1401161253452301},
#  '../policy_library/101_3.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/101_3_1e-1_blind.pth': {'Perimeter_top_ZN_3': 3.531729575456666e-08,
#   'Perimeter_bot_ZN_1': 3.531729575456666e-08,
#   'Perimeter_top_ZN_1': 3.531729575456666e-08,
#   'Core_bottom': 3.531729575456666e-08,
#   'Perimeter_top_ZN_4': 3.531729575456666e-08,
#   'Core_top': 3.531729575456666e-08,
#   'Perimeter_bot_ZN_2': 3.531729575456666e-08,
#   'Perimeter_bot_ZN_3': 3.531729575456666e-08,
#   'Perimeter_mid_ZN_4': 3.531729575456666e-08,
#   'Core_mid': 3.531729575456666e-08,
#   'Perimeter_mid_ZN_2': 3.531729575456666e-08,
#   'Perimeter_mid_ZN_3': 3.531729575456666e-08,
#   'Perimeter_top_ZN_2': 3.531729575456666e-08,
#   'Perimeter_mid_ZN_1': 3.531729575456666e-08,
#   'Perimeter_bot_ZN_4': 3.531729575456666e-08},
#  '../policy_library/101_3_1e0_blind.pth': {'Perimeter_top_ZN_3': 3.531729575456666e-08,
#   'Perimeter_bot_ZN_1': 3.531729575456666e-08,
#   'Perimeter_top_ZN_1': 3.531729575456666e-08,
#   'Core_bottom': 3.531729575456666e-08,
#   'Perimeter_top_ZN_4': 3.531729575456666e-08,
#   'Core_top': 3.531729575456666e-08,
#   'Perimeter_bot_ZN_2': 3.531729575456666e-08,
#   'Perimeter_bot_ZN_3': 3.531729575456666e-08,
#   'Perimeter_mid_ZN_4': 3.531729575456666e-08,
#   'Core_mid': 3.531729575456666e-08,
#   'Perimeter_mid_ZN_2': 3.531729575456666e-08,
#   'Perimeter_mid_ZN_3': 3.531729575456666e-08,
#   'Perimeter_top_ZN_2': 3.531729575456666e-08,
#   'Perimeter_mid_ZN_1': 3.531729575456666e-08,
#   'Perimeter_bot_ZN_4': 3.531729575456666e-08},
#  '../policy_library/101_3_1e1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/101_3_blind.pth': {'Perimeter_top_ZN_3': 0.4741263687610626,
#   'Perimeter_bot_ZN_1': 0.4741263687610626,
#   'Perimeter_top_ZN_1': 0.4741263687610626,
#   'Core_bottom': 0.4741263687610626,
#   'Perimeter_top_ZN_4': 0.4741263687610626,
#   'Core_top': 0.4741263687610626,
#   'Perimeter_bot_ZN_2': 0.4741263687610626,
#   'Perimeter_bot_ZN_3': 0.4741263687610626,
#   'Perimeter_mid_ZN_4': 0.4741263687610626,
#   'Core_mid': 0.4741263687610626,
#   'Perimeter_mid_ZN_2': 0.4741263687610626,
#   'Perimeter_mid_ZN_3': 0.4741263687610626,
#   'Perimeter_top_ZN_2': 0.4741263687610626,
#   'Perimeter_mid_ZN_1': 0.4741263687610626,
#   'Perimeter_bot_ZN_4': 0.4741263687610626},
#  '../policy_library/101_4.pth': {'Perimeter_top_ZN_3': 0.32730937004089355,
#   'Perimeter_bot_ZN_1': 0.32730937004089355,
#   'Perimeter_top_ZN_1': 0.32730937004089355,
#   'Core_bottom': 0.32730937004089355,
#   'Perimeter_top_ZN_4': 0.32730937004089355,
#   'Core_top': 0.32730937004089355,
#   'Perimeter_bot_ZN_2': 0.32730937004089355,
#   'Perimeter_bot_ZN_3': 0.32730937004089355,
#   'Perimeter_mid_ZN_4': 0.32730937004089355,
#   'Core_mid': 0.32730937004089355,
#   'Perimeter_mid_ZN_2': 0.32730937004089355,
#   'Perimeter_mid_ZN_3': 0.32730937004089355,
#   'Perimeter_top_ZN_2': 0.32730937004089355,
#   'Perimeter_mid_ZN_1': 0.32730937004089355,
#   'Perimeter_bot_ZN_4': 0.32730937004089355},
#  '../policy_library/101_4_1e-1_blind.pth': {'Perimeter_top_ZN_3': 1.3592929950026478e-12,
#   'Perimeter_bot_ZN_1': 1.3592929950026478e-12,
#   'Perimeter_top_ZN_1': 1.3592929950026478e-12,
#   'Core_bottom': 1.3592929950026478e-12,
#   'Perimeter_top_ZN_4': 1.3592929950026478e-12,
#   'Core_top': 1.3592929950026478e-12,
#   'Perimeter_bot_ZN_2': 1.3592929950026478e-12,
#   'Perimeter_bot_ZN_3': 1.3592929950026478e-12,
#   'Perimeter_mid_ZN_4': 1.3592929950026478e-12,
#   'Core_mid': 1.3592929950026478e-12,
#   'Perimeter_mid_ZN_2': 1.3592929950026478e-12,
#   'Perimeter_mid_ZN_3': 1.3592929950026478e-12,
#   'Perimeter_top_ZN_2': 1.3592929950026478e-12,
#   'Perimeter_mid_ZN_1': 1.3592929950026478e-12,
#   'Perimeter_bot_ZN_4': 1.3592929950026478e-12},
#  '../policy_library/101_4_1e0_blind.pth': {'Perimeter_top_ZN_3': 1.3592929950026478e-12,
#   'Perimeter_bot_ZN_1': 1.3592929950026478e-12,
#   'Perimeter_top_ZN_1': 1.3592929950026478e-12,
#   'Core_bottom': 1.3592929950026478e-12,
#   'Perimeter_top_ZN_4': 1.3592929950026478e-12,
#   'Core_top': 1.3592929950026478e-12,
#   'Perimeter_bot_ZN_2': 1.3592929950026478e-12,
#   'Perimeter_bot_ZN_3': 1.3592929950026478e-12,
#   'Perimeter_mid_ZN_4': 1.3592929950026478e-12,
#   'Core_mid': 1.3592929950026478e-12,
#   'Perimeter_mid_ZN_2': 1.3592929950026478e-12,
#   'Perimeter_mid_ZN_3': 1.3592929950026478e-12,
#   'Perimeter_top_ZN_2': 1.3592929950026478e-12,
#   'Perimeter_mid_ZN_1': 1.3592929950026478e-12,
#   'Perimeter_bot_ZN_4': 1.3592929950026478e-12},
#  '../policy_library/101_4_1e1_blind.pth': {'Perimeter_top_ZN_3': 8.956816673278809,
#   'Perimeter_bot_ZN_1': 8.956816673278809,
#   'Perimeter_top_ZN_1': 8.956816673278809,
#   'Core_bottom': 8.956816673278809,
#   'Perimeter_top_ZN_4': 8.956816673278809,
#   'Core_top': 8.956816673278809,
#   'Perimeter_bot_ZN_2': 8.956816673278809,
#   'Perimeter_bot_ZN_3': 8.956816673278809,
#   'Perimeter_mid_ZN_4': 8.956816673278809,
#   'Core_mid': 8.956816673278809,
#   'Perimeter_mid_ZN_2': 8.956816673278809,
#   'Perimeter_mid_ZN_3': 8.956816673278809,
#   'Perimeter_top_ZN_2': 8.956816673278809,
#   'Perimeter_mid_ZN_1': 8.956816673278809,
#   'Perimeter_bot_ZN_4': 8.956816673278809},
#  '../policy_library/101_4_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_0.pth': {'Perimeter_top_ZN_3': 5.014008143140042e-14,
#   'Perimeter_bot_ZN_1': 5.014008143140042e-14,
#   'Perimeter_top_ZN_1': 5.014008143140042e-14,
#   'Core_bottom': 5.014008143140042e-14,
#   'Perimeter_top_ZN_4': 5.014008143140042e-14,
#   'Core_top': 5.014008143140042e-14,
#   'Perimeter_bot_ZN_2': 5.014008143140042e-14,
#   'Perimeter_bot_ZN_3': 5.014008143140042e-14,
#   'Perimeter_mid_ZN_4': 5.014008143140042e-14,
#   'Core_mid': 5.014008143140042e-14,
#   'Perimeter_mid_ZN_2': 5.014008143140042e-14,
#   'Perimeter_mid_ZN_3': 5.014008143140042e-14,
#   'Perimeter_top_ZN_2': 5.014008143140042e-14,
#   'Perimeter_mid_ZN_1': 5.014008143140042e-14,
#   'Perimeter_bot_ZN_4': 5.014008143140042e-14},
#  '../policy_library/102_0_1e-1.pth': {'Perimeter_top_ZN_3': 9.800317610700677e-18,
#   'Perimeter_bot_ZN_1': 9.800317610700677e-18,
#   'Perimeter_top_ZN_1': 9.800317610700677e-18,
#   'Core_bottom': 9.800317610700677e-18,
#   'Perimeter_top_ZN_4': 9.800317610700677e-18,
#   'Core_top': 9.800317610700677e-18,
#   'Perimeter_bot_ZN_2': 9.800317610700677e-18,
#   'Perimeter_bot_ZN_3': 9.800317610700677e-18,
#   'Perimeter_mid_ZN_4': 9.800317610700677e-18,
#   'Core_mid': 9.800317610700677e-18,
#   'Perimeter_mid_ZN_2': 9.800317610700677e-18,
#   'Perimeter_mid_ZN_3': 9.800317610700677e-18,
#   'Perimeter_top_ZN_2': 9.800317610700677e-18,
#   'Perimeter_mid_ZN_1': 9.800317610700677e-18,
#   'Perimeter_bot_ZN_4': 9.800317610700677e-18},
#  '../policy_library/102_0_1e0.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_0_1e0_blind.pth': {'Perimeter_top_ZN_3': 0.0034587844274938107,
#   'Perimeter_bot_ZN_1': 0.0034587844274938107,
#   'Perimeter_top_ZN_1': 0.0034587844274938107,
#   'Core_bottom': 0.0034587844274938107,
#   'Perimeter_top_ZN_4': 0.0034587844274938107,
#   'Core_top': 0.0034587844274938107,
#   'Perimeter_bot_ZN_2': 0.0034587844274938107,
#   'Perimeter_bot_ZN_3': 0.0034587844274938107,
#   'Perimeter_mid_ZN_4': 0.0034587844274938107,
#   'Core_mid': 0.0034587844274938107,
#   'Perimeter_mid_ZN_2': 0.0034587844274938107,
#   'Perimeter_mid_ZN_3': 0.0034587844274938107,
#   'Perimeter_top_ZN_2': 0.0034587844274938107,
#   'Perimeter_mid_ZN_1': 0.0034587844274938107,
#   'Perimeter_bot_ZN_4': 0.0034587844274938107},
#  '../policy_library/102_0_1e1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_0_1e1_blind.pth': {'Perimeter_top_ZN_3': 4.465932398195482e-12,
#   'Perimeter_bot_ZN_1': 4.465932398195482e-12,
#   'Perimeter_top_ZN_1': 4.465932398195482e-12,
#   'Core_bottom': 4.465932398195482e-12,
#   'Perimeter_top_ZN_4': 4.465932398195482e-12,
#   'Core_top': 4.465932398195482e-12,
#   'Perimeter_bot_ZN_2': 4.465932398195482e-12,
#   'Perimeter_bot_ZN_3': 4.465932398195482e-12,
#   'Perimeter_mid_ZN_4': 4.465932398195482e-12,
#   'Core_mid': 4.465932398195482e-12,
#   'Perimeter_mid_ZN_2': 4.465932398195482e-12,
#   'Perimeter_mid_ZN_3': 4.465932398195482e-12,
#   'Perimeter_top_ZN_2': 4.465932398195482e-12,
#   'Perimeter_mid_ZN_1': 4.465932398195482e-12,
#   'Perimeter_bot_ZN_4': 4.465932398195482e-12},
#  '../policy_library/102_0_blind.pth': {'Perimeter_top_ZN_3': 3.2219507694244385,
#   'Perimeter_bot_ZN_1': 3.2219507694244385,
#   'Perimeter_top_ZN_1': 3.2219507694244385,
#   'Core_bottom': 3.2219507694244385,
#   'Perimeter_top_ZN_4': 3.2219507694244385,
#   'Core_top': 3.2219507694244385,
#   'Perimeter_bot_ZN_2': 3.2219507694244385,
#   'Perimeter_bot_ZN_3': 3.2219507694244385,
#   'Perimeter_mid_ZN_4': 3.2219507694244385,
#   'Core_mid': 3.2219507694244385,
#   'Perimeter_mid_ZN_2': 3.2219507694244385,
#   'Perimeter_mid_ZN_3': 3.2219507694244385,
#   'Perimeter_top_ZN_2': 3.2219507694244385,
#   'Perimeter_mid_ZN_1': 3.2219507694244385,
#   'Perimeter_bot_ZN_4': 3.2219507694244385},
#  '../policy_library/102_1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_1_1e-1.pth': {'Perimeter_top_ZN_3': 0.6290679574012756,
#   'Perimeter_bot_ZN_1': 0.6290679574012756,
#   'Perimeter_top_ZN_1': 0.6290679574012756,
#   'Core_bottom': 0.6290679574012756,
#   'Perimeter_top_ZN_4': 0.6290679574012756,
#   'Core_top': 0.6290679574012756,
#   'Perimeter_bot_ZN_2': 0.6290679574012756,
#   'Perimeter_bot_ZN_3': 0.6290679574012756,
#   'Perimeter_mid_ZN_4': 0.6290679574012756,
#   'Core_mid': 0.6290679574012756,
#   'Perimeter_mid_ZN_2': 0.6290679574012756,
#   'Perimeter_mid_ZN_3': 0.6290679574012756,
#   'Perimeter_top_ZN_2': 0.6290679574012756,
#   'Perimeter_mid_ZN_1': 0.6290679574012756,
#   'Perimeter_bot_ZN_4': 0.6290679574012756},
#  '../policy_library/102_1_1e0_blind.pth': {'Perimeter_top_ZN_3': 0.08178971707820892,
#   'Perimeter_bot_ZN_1': 0.08178971707820892,
#   'Perimeter_top_ZN_1': 0.08178971707820892,
#   'Core_bottom': 0.08178971707820892,
#   'Perimeter_top_ZN_4': 0.08178971707820892,
#   'Core_top': 0.08178971707820892,
#   'Perimeter_bot_ZN_2': 0.08178971707820892,
#   'Perimeter_bot_ZN_3': 0.08178971707820892,
#   'Perimeter_mid_ZN_4': 0.08178971707820892,
#   'Core_mid': 0.08178971707820892,
#   'Perimeter_mid_ZN_2': 0.08178971707820892,
#   'Perimeter_mid_ZN_3': 0.08178971707820892,
#   'Perimeter_top_ZN_2': 0.08178971707820892,
#   'Perimeter_mid_ZN_1': 0.08178971707820892,
#   'Perimeter_bot_ZN_4': 0.08178971707820892},
#  '../policy_library/102_1_blind.pth': {'Perimeter_top_ZN_3': 0.05951865389943123,
#   'Perimeter_bot_ZN_1': 0.05951865389943123,
#   'Perimeter_top_ZN_1': 0.05951865389943123,
#   'Core_bottom': 0.05951865389943123,
#   'Perimeter_top_ZN_4': 0.05951865389943123,
#   'Core_top': 0.05951865389943123,
#   'Perimeter_bot_ZN_2': 0.05951865389943123,
#   'Perimeter_bot_ZN_3': 0.05951865389943123,
#   'Perimeter_mid_ZN_4': 0.05951865389943123,
#   'Core_mid': 0.05951865389943123,
#   'Perimeter_mid_ZN_2': 0.05951865389943123,
#   'Perimeter_mid_ZN_3': 0.05951865389943123,
#   'Perimeter_top_ZN_2': 0.05951865389943123,
#   'Perimeter_mid_ZN_1': 0.05951865389943123,
#   'Perimeter_bot_ZN_4': 0.05951865389943123},
#  '../policy_library/102_2.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_2_1e-1.pth': {'Perimeter_top_ZN_3': 2.1962098144668258e-18,
#   'Perimeter_bot_ZN_1': 2.1962098144668258e-18,
#   'Perimeter_top_ZN_1': 2.1962098144668258e-18,
#   'Core_bottom': 2.1962098144668258e-18,
#   'Perimeter_top_ZN_4': 2.1962098144668258e-18,
#   'Core_top': 2.1962098144668258e-18,
#   'Perimeter_bot_ZN_2': 2.1962098144668258e-18,
#   'Perimeter_bot_ZN_3': 2.1962098144668258e-18,
#   'Perimeter_mid_ZN_4': 2.1962098144668258e-18,
#   'Core_mid': 2.1962098144668258e-18,
#   'Perimeter_mid_ZN_2': 2.1962098144668258e-18,
#   'Perimeter_mid_ZN_3': 2.1962098144668258e-18,
#   'Perimeter_top_ZN_2': 2.1962098144668258e-18,
#   'Perimeter_mid_ZN_1': 2.1962098144668258e-18,
#   'Perimeter_bot_ZN_4': 2.1962098144668258e-18},
#  '../policy_library/102_2_1e0_blind.pth': {'Perimeter_top_ZN_3': 3.9413580894470215,
#   'Perimeter_bot_ZN_1': 3.9413580894470215,
#   'Perimeter_top_ZN_1': 3.9413580894470215,
#   'Core_bottom': 3.9413580894470215,
#   'Perimeter_top_ZN_4': 3.9413580894470215,
#   'Core_top': 3.9413580894470215,
#   'Perimeter_bot_ZN_2': 3.9413580894470215,
#   'Perimeter_bot_ZN_3': 3.9413580894470215,
#   'Perimeter_mid_ZN_4': 3.9413580894470215,
#   'Core_mid': 3.9413580894470215,
#   'Perimeter_mid_ZN_2': 3.9413580894470215,
#   'Perimeter_mid_ZN_3': 3.9413580894470215,
#   'Perimeter_top_ZN_2': 3.9413580894470215,
#   'Perimeter_mid_ZN_1': 3.9413580894470215,
#   'Perimeter_bot_ZN_4': 3.9413580894470215},
#  '../policy_library/102_2_1e1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_2_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_3.pth': {'Perimeter_top_ZN_3': 6.906029739184305e-06,
#   'Perimeter_bot_ZN_1': 6.906029739184305e-06,
#   'Perimeter_top_ZN_1': 6.906029739184305e-06,
#   'Core_bottom': 6.906029739184305e-06,
#   'Perimeter_top_ZN_4': 6.906029739184305e-06,
#   'Core_top': 6.906029739184305e-06,
#   'Perimeter_bot_ZN_2': 6.906029739184305e-06,
#   'Perimeter_bot_ZN_3': 6.906029739184305e-06,
#   'Perimeter_mid_ZN_4': 6.906029739184305e-06,
#   'Core_mid': 6.906029739184305e-06,
#   'Perimeter_mid_ZN_2': 6.906029739184305e-06,
#   'Perimeter_mid_ZN_3': 6.906029739184305e-06,
#   'Perimeter_top_ZN_2': 6.906029739184305e-06,
#   'Perimeter_mid_ZN_1': 6.906029739184305e-06,
#   'Perimeter_bot_ZN_4': 6.906029739184305e-06},
#  '../policy_library/102_3_1e-1.pth': {'Perimeter_top_ZN_3': 1.166378024208825e-05,
#   'Perimeter_bot_ZN_1': 1.166378024208825e-05,
#   'Perimeter_top_ZN_1': 1.166378024208825e-05,
#   'Core_bottom': 1.166378024208825e-05,
#   'Perimeter_top_ZN_4': 1.166378024208825e-05,
#   'Core_top': 1.166378024208825e-05,
#   'Perimeter_bot_ZN_2': 1.166378024208825e-05,
#   'Perimeter_bot_ZN_3': 1.166378024208825e-05,
#   'Perimeter_mid_ZN_4': 1.166378024208825e-05,
#   'Core_mid': 1.166378024208825e-05,
#   'Perimeter_mid_ZN_2': 1.166378024208825e-05,
#   'Perimeter_mid_ZN_3': 1.166378024208825e-05,
#   'Perimeter_top_ZN_2': 1.166378024208825e-05,
#   'Perimeter_mid_ZN_1': 1.166378024208825e-05,
#   'Perimeter_bot_ZN_4': 1.166378024208825e-05},
#  '../policy_library/102_3_1e-1_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_3_1e0.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_3_1e0_blind.pth': {'Perimeter_top_ZN_3': 1.4995162197610022e-18,
#   'Perimeter_bot_ZN_1': 1.4995162197610022e-18,
#   'Perimeter_top_ZN_1': 1.4995162197610022e-18,
#   'Core_bottom': 1.4995162197610022e-18,
#   'Perimeter_top_ZN_4': 1.4995162197610022e-18,
#   'Core_top': 1.4995162197610022e-18,
#   'Perimeter_bot_ZN_2': 1.4995162197610022e-18,
#   'Perimeter_bot_ZN_3': 1.4995162197610022e-18,
#   'Perimeter_mid_ZN_4': 1.4995162197610022e-18,
#   'Core_mid': 1.4995162197610022e-18,
#   'Perimeter_mid_ZN_2': 1.4995162197610022e-18,
#   'Perimeter_mid_ZN_3': 1.4995162197610022e-18,
#   'Perimeter_top_ZN_2': 1.4995162197610022e-18,
#   'Perimeter_mid_ZN_1': 1.4995162197610022e-18,
#   'Perimeter_bot_ZN_4': 1.4995162197610022e-18},
#  '../policy_library/102_3_1e1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_3_1e1_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_3_blind.pth': {'Perimeter_top_ZN_3': 2.7648496627807617,
#   'Perimeter_bot_ZN_1': 2.7648496627807617,
#   'Perimeter_top_ZN_1': 2.7648496627807617,
#   'Core_bottom': 2.7648496627807617,
#   'Perimeter_top_ZN_4': 2.7648496627807617,
#   'Core_top': 2.7648496627807617,
#   'Perimeter_bot_ZN_2': 2.7648496627807617,
#   'Perimeter_bot_ZN_3': 2.7648496627807617,
#   'Perimeter_mid_ZN_4': 2.7648496627807617,
#   'Core_mid': 2.7648496627807617,
#   'Perimeter_mid_ZN_2': 2.7648496627807617,
#   'Perimeter_mid_ZN_3': 2.7648496627807617,
#   'Perimeter_top_ZN_2': 2.7648496627807617,
#   'Perimeter_mid_ZN_1': 2.7648496627807617,
#   'Perimeter_bot_ZN_4': 2.7648496627807617},
#  '../policy_library/102_4.pth': {'Perimeter_top_ZN_3': 5.083411693572998,
#   'Perimeter_bot_ZN_1': 5.083411693572998,
#   'Perimeter_top_ZN_1': 5.083411693572998,
#   'Core_bottom': 5.083411693572998,
#   'Perimeter_top_ZN_4': 5.083411693572998,
#   'Core_top': 5.083411693572998,
#   'Perimeter_bot_ZN_2': 5.083411693572998,
#   'Perimeter_bot_ZN_3': 5.083411693572998,
#   'Perimeter_mid_ZN_4': 5.083411693572998,
#   'Core_mid': 5.083411693572998,
#   'Perimeter_mid_ZN_2': 5.083411693572998,
#   'Perimeter_mid_ZN_3': 5.083411693572998,
#   'Perimeter_top_ZN_2': 5.083411693572998,
#   'Perimeter_mid_ZN_1': 5.083411693572998,
#   'Perimeter_bot_ZN_4': 5.083411693572998},
#  '../policy_library/102_4_1e-1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_4_1e1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_4_1e1_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/102_4_blind.pth': {'Perimeter_top_ZN_3': 0.28419259190559387,
#   'Perimeter_bot_ZN_1': 0.28419259190559387,
#   'Perimeter_top_ZN_1': 0.28419259190559387,
#   'Core_bottom': 0.28419259190559387,
#   'Perimeter_top_ZN_4': 0.28419259190559387,
#   'Core_top': 0.28419259190559387,
#   'Perimeter_bot_ZN_2': 0.28419259190559387,
#   'Perimeter_bot_ZN_3': 0.28419259190559387,
#   'Perimeter_mid_ZN_4': 0.28419259190559387,
#   'Core_mid': 0.28419259190559387,
#   'Perimeter_mid_ZN_2': 0.28419259190559387,
#   'Perimeter_mid_ZN_3': 0.28419259190559387,
#   'Perimeter_top_ZN_2': 0.28419259190559387,
#   'Perimeter_mid_ZN_1': 0.28419259190559387,
#   'Perimeter_bot_ZN_4': 0.28419259190559387},
#  '../policy_library/103_0.pth': {'Perimeter_top_ZN_3': 0.06378988921642303,
#   'Perimeter_bot_ZN_1': 0.06378988921642303,
#   'Perimeter_top_ZN_1': 0.06378988921642303,
#   'Core_bottom': 0.06378988921642303,
#   'Perimeter_top_ZN_4': 0.06378988921642303,
#   'Core_top': 0.06378988921642303,
#   'Perimeter_bot_ZN_2': 0.06378988921642303,
#   'Perimeter_bot_ZN_3': 0.06378988921642303,
#   'Perimeter_mid_ZN_4': 0.06378988921642303,
#   'Core_mid': 0.06378988921642303,
#   'Perimeter_mid_ZN_2': 0.06378988921642303,
#   'Perimeter_mid_ZN_3': 0.06378988921642303,
#   'Perimeter_top_ZN_2': 0.06378988921642303,
#   'Perimeter_mid_ZN_1': 0.06378988921642303,
#   'Perimeter_bot_ZN_4': 0.06378988921642303},
#  '../policy_library/103_0_1e-1.pth': {'Perimeter_top_ZN_3': 0.0006049993680790067,
#   'Perimeter_bot_ZN_1': 0.0006049993680790067,
#   'Perimeter_top_ZN_1': 0.0006049993680790067,
#   'Core_bottom': 0.0006049993680790067,
#   'Perimeter_top_ZN_4': 0.0006049993680790067,
#   'Core_top': 0.0006049993680790067,
#   'Perimeter_bot_ZN_2': 0.0006049993680790067,
#   'Perimeter_bot_ZN_3': 0.0006049993680790067,
#   'Perimeter_mid_ZN_4': 0.0006049993680790067,
#   'Core_mid': 0.0006049993680790067,
#   'Perimeter_mid_ZN_2': 0.0006049993680790067,
#   'Perimeter_mid_ZN_3': 0.0006049993680790067,
#   'Perimeter_top_ZN_2': 0.0006049993680790067,
#   'Perimeter_mid_ZN_1': 0.0006049993680790067,
#   'Perimeter_bot_ZN_4': 0.0006049993680790067},
#  '../policy_library/103_0_1e0.pth': {'Perimeter_top_ZN_3': 0.0006049993680790067,
#   'Perimeter_bot_ZN_1': 0.0006049993680790067,
#   'Perimeter_top_ZN_1': 0.0006049993680790067,
#   'Core_bottom': 0.0006049993680790067,
#   'Perimeter_top_ZN_4': 0.0006049993680790067,
#   'Core_top': 0.0006049993680790067,
#   'Perimeter_bot_ZN_2': 0.0006049993680790067,
#   'Perimeter_bot_ZN_3': 0.0006049993680790067,
#   'Perimeter_mid_ZN_4': 0.0006049993680790067,
#   'Core_mid': 0.0006049993680790067,
#   'Perimeter_mid_ZN_2': 0.0006049993680790067,
#   'Perimeter_mid_ZN_3': 0.0006049993680790067,
#   'Perimeter_top_ZN_2': 0.0006049993680790067,
#   'Perimeter_mid_ZN_1': 0.0006049993680790067,
#   'Perimeter_bot_ZN_4': 0.0006049993680790067},
#  '../policy_library/103_0_1e1.pth': {'Perimeter_top_ZN_3': 0.0006049993680790067,
#   'Perimeter_bot_ZN_1': 0.0006049993680790067,
#   'Perimeter_top_ZN_1': 0.0006049993680790067,
#   'Core_bottom': 0.0006049993680790067,
#   'Perimeter_top_ZN_4': 0.0006049993680790067,
#   'Core_top': 0.0006049993680790067,
#   'Perimeter_bot_ZN_2': 0.0006049993680790067,
#   'Perimeter_bot_ZN_3': 0.0006049993680790067,
#   'Perimeter_mid_ZN_4': 0.0006049993680790067,
#   'Core_mid': 0.0006049993680790067,
#   'Perimeter_mid_ZN_2': 0.0006049993680790067,
#   'Perimeter_mid_ZN_3': 0.0006049993680790067,
#   'Perimeter_top_ZN_2': 0.0006049993680790067,
#   'Perimeter_mid_ZN_1': 0.0006049993680790067,
#   'Perimeter_bot_ZN_4': 0.0006049993680790067},
#  '../policy_library/103_0_blind.pth': {'Perimeter_top_ZN_3': 2.934335708618164,
#   'Perimeter_bot_ZN_1': 2.934335708618164,
#   'Perimeter_top_ZN_1': 2.934335708618164,
#   'Core_bottom': 2.934335708618164,
#   'Perimeter_top_ZN_4': 2.934335708618164,
#   'Core_top': 2.934335708618164,
#   'Perimeter_bot_ZN_2': 2.934335708618164,
#   'Perimeter_bot_ZN_3': 2.934335708618164,
#   'Perimeter_mid_ZN_4': 2.934335708618164,
#   'Core_mid': 2.934335708618164,
#   'Perimeter_mid_ZN_2': 2.934335708618164,
#   'Perimeter_mid_ZN_3': 2.934335708618164,
#   'Perimeter_top_ZN_2': 2.934335708618164,
#   'Perimeter_mid_ZN_1': 2.934335708618164,
#   'Perimeter_bot_ZN_4': 2.934335708618164},
#  '../policy_library/103_1.pth': {'Perimeter_top_ZN_3': 1.4208662509918213,
#   'Perimeter_bot_ZN_1': 1.4208662509918213,
#   'Perimeter_top_ZN_1': 1.4208662509918213,
#   'Core_bottom': 1.4208662509918213,
#   'Perimeter_top_ZN_4': 1.4208662509918213,
#   'Core_top': 1.4208662509918213,
#   'Perimeter_bot_ZN_2': 1.4208662509918213,
#   'Perimeter_bot_ZN_3': 1.4208662509918213,
#   'Perimeter_mid_ZN_4': 1.4208662509918213,
#   'Core_mid': 1.4208662509918213,
#   'Perimeter_mid_ZN_2': 1.4208662509918213,
#   'Perimeter_mid_ZN_3': 1.4208662509918213,
#   'Perimeter_top_ZN_2': 1.4208662509918213,
#   'Perimeter_mid_ZN_1': 1.4208662509918213,
#   'Perimeter_bot_ZN_4': 1.4208662509918213},
#  '../policy_library/103_1_1e-1.pth': {'Perimeter_top_ZN_3': 5.612138920696452e-06,
#   'Perimeter_bot_ZN_1': 5.612138920696452e-06,
#   'Perimeter_top_ZN_1': 5.612138920696452e-06,
#   'Core_bottom': 5.612138920696452e-06,
#   'Perimeter_top_ZN_4': 5.612138920696452e-06,
#   'Core_top': 5.612138920696452e-06,
#   'Perimeter_bot_ZN_2': 5.612138920696452e-06,
#   'Perimeter_bot_ZN_3': 5.612138920696452e-06,
#   'Perimeter_mid_ZN_4': 5.612138920696452e-06,
#   'Core_mid': 5.612138920696452e-06,
#   'Perimeter_mid_ZN_2': 5.612138920696452e-06,
#   'Perimeter_mid_ZN_3': 5.612138920696452e-06,
#   'Perimeter_top_ZN_2': 5.612138920696452e-06,
#   'Perimeter_mid_ZN_1': 5.612138920696452e-06,
#   'Perimeter_bot_ZN_4': 5.612138920696452e-06},
#  '../policy_library/103_1_1e-1_blind.pth': {'Perimeter_top_ZN_3': 12.840909957885742,
#   'Perimeter_bot_ZN_1': 12.840909957885742,
#   'Perimeter_top_ZN_1': 12.840909957885742,
#   'Core_bottom': 12.840909957885742,
#   'Perimeter_top_ZN_4': 12.840909957885742,
#   'Core_top': 12.840909957885742,
#   'Perimeter_bot_ZN_2': 12.840909957885742,
#   'Perimeter_bot_ZN_3': 12.840909957885742,
#   'Perimeter_mid_ZN_4': 12.840909957885742,
#   'Core_mid': 12.840909957885742,
#   'Perimeter_mid_ZN_2': 12.840909957885742,
#   'Perimeter_mid_ZN_3': 12.840909957885742,
#   'Perimeter_top_ZN_2': 12.840909957885742,
#   'Perimeter_mid_ZN_1': 12.840909957885742,
#   'Perimeter_bot_ZN_4': 12.840909957885742},
#  '../policy_library/103_1_1e0.pth': {'Perimeter_top_ZN_3': 5.612138920696452e-06,
#   'Perimeter_bot_ZN_1': 5.612138920696452e-06,
#   'Perimeter_top_ZN_1': 5.612138920696452e-06,
#   'Core_bottom': 5.612138920696452e-06,
#   'Perimeter_top_ZN_4': 5.612138920696452e-06,
#   'Core_top': 5.612138920696452e-06,
# ...
#   'Perimeter_top_ZN_2': 4.698545025272338e-11,
#   'Perimeter_mid_ZN_1': 4.698545025272338e-11,
#   'Perimeter_bot_ZN_4': 4.698545025272338e-11},
#  '../policy_library/118_4_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/119_0.pth': {'Perimeter_top_ZN_3': 11.204405784606934,
#   'Perimeter_bot_ZN_1': 11.204405784606934,
#   'Perimeter_top_ZN_1': 11.204405784606934,
#   'Core_bottom': 11.204405784606934,
#   'Perimeter_top_ZN_4': 11.204405784606934,
#   'Core_top': 11.204405784606934,
#   'Perimeter_bot_ZN_2': 11.204405784606934,
#   'Perimeter_bot_ZN_3': 11.204405784606934,
#   'Perimeter_mid_ZN_4': 11.204405784606934,
#   'Core_mid': 11.204405784606934,
#   'Perimeter_mid_ZN_2': 11.204405784606934,
#   'Perimeter_mid_ZN_3': 11.204405784606934,
#   'Perimeter_top_ZN_2': 11.204405784606934,
#   'Perimeter_mid_ZN_1': 11.204405784606934,
#   'Perimeter_bot_ZN_4': 11.204405784606934},
#  '../policy_library/119_0_1e0.pth': {'Perimeter_top_ZN_3': 1.7768933773040771,
#   'Perimeter_bot_ZN_1': 1.7768933773040771,
#   'Perimeter_top_ZN_1': 1.7768933773040771,
#   'Core_bottom': 1.7768933773040771,
#   'Perimeter_top_ZN_4': 1.7768933773040771,
#   'Core_top': 1.7768933773040771,
#   'Perimeter_bot_ZN_2': 1.7768933773040771,
#   'Perimeter_bot_ZN_3': 1.7768933773040771,
#   'Perimeter_mid_ZN_4': 1.7768933773040771,
#   'Core_mid': 1.7768933773040771,
#   'Perimeter_mid_ZN_2': 1.7768933773040771,
#   'Perimeter_mid_ZN_3': 1.7768933773040771,
#   'Perimeter_top_ZN_2': 1.7768933773040771,
#   'Perimeter_mid_ZN_1': 1.7768933773040771,
#   'Perimeter_bot_ZN_4': 1.7768933773040771},
#  '../policy_library/119_0_1e1.pth': {'Perimeter_top_ZN_3': 0.003911176230758429,
#   'Perimeter_bot_ZN_1': 0.003911176230758429,
#   'Perimeter_top_ZN_1': 0.003911176230758429,
#   'Core_bottom': 0.003911176230758429,
#   'Perimeter_top_ZN_4': 0.003911176230758429,
#   'Core_top': 0.003911176230758429,
#   'Perimeter_bot_ZN_2': 0.003911176230758429,
#   'Perimeter_bot_ZN_3': 0.003911176230758429,
#   'Perimeter_mid_ZN_4': 0.003911176230758429,
#   'Core_mid': 0.003911176230758429,
#   'Perimeter_mid_ZN_2': 0.003911176230758429,
#   'Perimeter_mid_ZN_3': 0.003911176230758429,
#   'Perimeter_top_ZN_2': 0.003911176230758429,
#   'Perimeter_mid_ZN_1': 0.003911176230758429,
#   'Perimeter_bot_ZN_4': 0.003911176230758429},
#  '../policy_library/119_0_1e1_blind.pth': {'Perimeter_top_ZN_3': 1.7361940145492554,
#   'Perimeter_bot_ZN_1': 1.7361940145492554,
#   'Perimeter_top_ZN_1': 1.7361940145492554,
#   'Core_bottom': 1.7361940145492554,
#   'Perimeter_top_ZN_4': 1.7361940145492554,
#   'Core_top': 1.7361940145492554,
#   'Perimeter_bot_ZN_2': 1.7361940145492554,
#   'Perimeter_bot_ZN_3': 1.7361940145492554,
#   'Perimeter_mid_ZN_4': 1.7361940145492554,
#   'Core_mid': 1.7361940145492554,
#   'Perimeter_mid_ZN_2': 1.7361940145492554,
#   'Perimeter_mid_ZN_3': 1.7361940145492554,
#   'Perimeter_top_ZN_2': 1.7361940145492554,
#   'Perimeter_mid_ZN_1': 1.7361940145492554,
#   'Perimeter_bot_ZN_4': 1.7361940145492554},
#  '../policy_library/119_0_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/119_1.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/119_1_1e-1_blind.pth': {'Perimeter_top_ZN_3': 17.610769271850586,
#   'Perimeter_bot_ZN_1': 17.610769271850586,
#   'Perimeter_top_ZN_1': 17.610769271850586,
#   'Core_bottom': 17.610769271850586,
#   'Perimeter_top_ZN_4': 17.610769271850586,
#   'Core_top': 17.610769271850586,
#   'Perimeter_bot_ZN_2': 17.610769271850586,
#   'Perimeter_bot_ZN_3': 17.610769271850586,
#   'Perimeter_mid_ZN_4': 17.610769271850586,
#   'Core_mid': 17.610769271850586,
#   'Perimeter_mid_ZN_2': 17.610769271850586,
#   'Perimeter_mid_ZN_3': 17.610769271850586,
#   'Perimeter_top_ZN_2': 17.610769271850586,
#   'Perimeter_mid_ZN_1': 17.610769271850586,
#   'Perimeter_bot_ZN_4': 17.610769271850586},
#  '../policy_library/119_1_1e0.pth': {'Perimeter_top_ZN_3': 2.0476665812209313e-17,
#   'Perimeter_bot_ZN_1': 2.0476665812209313e-17,
#   'Perimeter_top_ZN_1': 2.0476665812209313e-17,
#   'Core_bottom': 2.0476665812209313e-17,
#   'Perimeter_top_ZN_4': 2.0476665812209313e-17,
#   'Core_top': 2.0476665812209313e-17,
#   'Perimeter_bot_ZN_2': 2.0476665812209313e-17,
#   'Perimeter_bot_ZN_3': 2.0476665812209313e-17,
#   'Perimeter_mid_ZN_4': 2.0476665812209313e-17,
#   'Core_mid': 2.0476665812209313e-17,
#   'Perimeter_mid_ZN_2': 2.0476665812209313e-17,
#   'Perimeter_mid_ZN_3': 2.0476665812209313e-17,
#   'Perimeter_top_ZN_2': 2.0476665812209313e-17,
#   'Perimeter_mid_ZN_1': 2.0476665812209313e-17,
#   'Perimeter_bot_ZN_4': 2.0476665812209313e-17},
#  '../policy_library/119_1_1e0_blind.pth': {'Perimeter_top_ZN_3': 4.523918151855469,
#   'Perimeter_bot_ZN_1': 4.523918151855469,
#   'Perimeter_top_ZN_1': 4.523918151855469,
#   'Core_bottom': 4.523918151855469,
#   'Perimeter_top_ZN_4': 4.523918151855469,
#   'Core_top': 4.523918151855469,
#   'Perimeter_bot_ZN_2': 4.523918151855469,
#   'Perimeter_bot_ZN_3': 4.523918151855469,
#   'Perimeter_mid_ZN_4': 4.523918151855469,
#   'Core_mid': 4.523918151855469,
#   'Perimeter_mid_ZN_2': 4.523918151855469,
#   'Perimeter_mid_ZN_3': 4.523918151855469,
#   'Perimeter_top_ZN_2': 4.523918151855469,
#   'Perimeter_mid_ZN_1': 4.523918151855469,
#   'Perimeter_bot_ZN_4': 4.523918151855469},
#  '../policy_library/119_1_1e1_blind.pth': {'Perimeter_top_ZN_3': 1.2045913623254522e-16,
#   'Perimeter_bot_ZN_1': 1.2045913623254522e-16,
#   'Perimeter_top_ZN_1': 1.2045913623254522e-16,
#   'Core_bottom': 1.2045913623254522e-16,
#   'Perimeter_top_ZN_4': 1.2045913623254522e-16,
#   'Core_top': 1.2045913623254522e-16,
#   'Perimeter_bot_ZN_2': 1.2045913623254522e-16,
#   'Perimeter_bot_ZN_3': 1.2045913623254522e-16,
#   'Perimeter_mid_ZN_4': 1.2045913623254522e-16,
#   'Core_mid': 1.2045913623254522e-16,
#   'Perimeter_mid_ZN_2': 1.2045913623254522e-16,
#   'Perimeter_mid_ZN_3': 1.2045913623254522e-16,
#   'Perimeter_top_ZN_2': 1.2045913623254522e-16,
#   'Perimeter_mid_ZN_1': 1.2045913623254522e-16,
#   'Perimeter_bot_ZN_4': 1.2045913623254522e-16},
#  '../policy_library/119_1_blind.pth': {'Perimeter_top_ZN_3': 0.9971157312393188,
#   'Perimeter_bot_ZN_1': 0.9971157312393188,
#   'Perimeter_top_ZN_1': 0.9971157312393188,
#   'Core_bottom': 0.9971157312393188,
#   'Perimeter_top_ZN_4': 0.9971157312393188,
#   'Core_top': 0.9971157312393188,
#   'Perimeter_bot_ZN_2': 0.9971157312393188,
#   'Perimeter_bot_ZN_3': 0.9971157312393188,
#   'Perimeter_mid_ZN_4': 0.9971157312393188,
#   'Core_mid': 0.9971157312393188,
#   'Perimeter_mid_ZN_2': 0.9971157312393188,
#   'Perimeter_mid_ZN_3': 0.9971157312393188,
#   'Perimeter_top_ZN_2': 0.9971157312393188,
#   'Perimeter_mid_ZN_1': 0.9971157312393188,
#   'Perimeter_bot_ZN_4': 0.9971157312393188},
#  '../policy_library/119_2.pth': {'Perimeter_top_ZN_3': 1.254378080368042,
#   'Perimeter_bot_ZN_1': 1.254378080368042,
#   'Perimeter_top_ZN_1': 1.254378080368042,
#   'Core_bottom': 1.254378080368042,
#   'Perimeter_top_ZN_4': 1.254378080368042,
#   'Core_top': 1.254378080368042,
#   'Perimeter_bot_ZN_2': 1.254378080368042,
#   'Perimeter_bot_ZN_3': 1.254378080368042,
#   'Perimeter_mid_ZN_4': 1.254378080368042,
#   'Core_mid': 1.254378080368042,
#   'Perimeter_mid_ZN_2': 1.254378080368042,
#   'Perimeter_mid_ZN_3': 1.254378080368042,
#   'Perimeter_top_ZN_2': 1.254378080368042,
#   'Perimeter_mid_ZN_1': 1.254378080368042,
#   'Perimeter_bot_ZN_4': 1.254378080368042},
#  '../policy_library/119_2_1e0.pth': {'Perimeter_top_ZN_3': 7.630760956089944e-05,
#   'Perimeter_bot_ZN_1': 7.630760956089944e-05,
#   'Perimeter_top_ZN_1': 7.630760956089944e-05,
#   'Core_bottom': 7.630760956089944e-05,
#   'Perimeter_top_ZN_4': 7.630760956089944e-05,
#   'Core_top': 7.630760956089944e-05,
#   'Perimeter_bot_ZN_2': 7.630760956089944e-05,
#   'Perimeter_bot_ZN_3': 7.630760956089944e-05,
#   'Perimeter_mid_ZN_4': 7.630760956089944e-05,
#   'Core_mid': 7.630760956089944e-05,
#   'Perimeter_mid_ZN_2': 7.630760956089944e-05,
#   'Perimeter_mid_ZN_3': 7.630760956089944e-05,
#   'Perimeter_top_ZN_2': 7.630760956089944e-05,
#   'Perimeter_mid_ZN_1': 7.630760956089944e-05,
#   'Perimeter_bot_ZN_4': 7.630760956089944e-05},
#  '../policy_library/119_2_1e1.pth': {'Perimeter_top_ZN_3': 17.717065811157227,
#   'Perimeter_bot_ZN_1': 17.717065811157227,
#   'Perimeter_top_ZN_1': 17.717065811157227,
#   'Core_bottom': 17.717065811157227,
#   'Perimeter_top_ZN_4': 17.717065811157227,
#   'Core_top': 17.717065811157227,
#   'Perimeter_bot_ZN_2': 17.717065811157227,
#   'Perimeter_bot_ZN_3': 17.717065811157227,
#   'Perimeter_mid_ZN_4': 17.717065811157227,
#   'Core_mid': 17.717065811157227,
#   'Perimeter_mid_ZN_2': 17.717065811157227,
#   'Perimeter_mid_ZN_3': 17.717065811157227,
#   'Perimeter_top_ZN_2': 17.717065811157227,
#   'Perimeter_mid_ZN_1': 17.717065811157227,
#   'Perimeter_bot_ZN_4': 17.717065811157227},
#  '../policy_library/119_2_1e1_blind.pth': {'Perimeter_top_ZN_3': 8.111593388093752e-07,
#   'Perimeter_bot_ZN_1': 8.111593388093752e-07,
#   'Perimeter_top_ZN_1': 8.111593388093752e-07,
#   'Core_bottom': 8.111593388093752e-07,
#   'Perimeter_top_ZN_4': 8.111593388093752e-07,
#   'Core_top': 8.111593388093752e-07,
#   'Perimeter_bot_ZN_2': 8.111593388093752e-07,
#   'Perimeter_bot_ZN_3': 8.111593388093752e-07,
#   'Perimeter_mid_ZN_4': 8.111593388093752e-07,
#   'Core_mid': 8.111593388093752e-07,
#   'Perimeter_mid_ZN_2': 8.111593388093752e-07,
#   'Perimeter_mid_ZN_3': 8.111593388093752e-07,
#   'Perimeter_top_ZN_2': 8.111593388093752e-07,
#   'Perimeter_mid_ZN_1': 8.111593388093752e-07,
#   'Perimeter_bot_ZN_4': 8.111593388093752e-07},
#  '../policy_library/119_2_blind.pth': {'Perimeter_top_ZN_3': 1.144840121269226,
#   'Perimeter_bot_ZN_1': 1.144840121269226,
#   'Perimeter_top_ZN_1': 1.144840121269226,
#   'Core_bottom': 1.144840121269226,
#   'Perimeter_top_ZN_4': 1.144840121269226,
#   'Core_top': 1.144840121269226,
#   'Perimeter_bot_ZN_2': 1.144840121269226,
#   'Perimeter_bot_ZN_3': 1.144840121269226,
#   'Perimeter_mid_ZN_4': 1.144840121269226,
#   'Core_mid': 1.144840121269226,
#   'Perimeter_mid_ZN_2': 1.144840121269226,
#   'Perimeter_mid_ZN_3': 1.144840121269226,
#   'Perimeter_top_ZN_2': 1.144840121269226,
#   'Perimeter_mid_ZN_1': 1.144840121269226,
#   'Perimeter_bot_ZN_4': 1.144840121269226},
#  '../policy_library/119_3.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/119_3_1e0.pth': {'Perimeter_top_ZN_3': 7.321588782360777e-06,
#   'Perimeter_bot_ZN_1': 7.321588782360777e-06,
#   'Perimeter_top_ZN_1': 7.321588782360777e-06,
#   'Core_bottom': 7.321588782360777e-06,
#   'Perimeter_top_ZN_4': 7.321588782360777e-06,
#   'Core_top': 7.321588782360777e-06,
#   'Perimeter_bot_ZN_2': 7.321588782360777e-06,
#   'Perimeter_bot_ZN_3': 7.321588782360777e-06,
#   'Perimeter_mid_ZN_4': 7.321588782360777e-06,
#   'Core_mid': 7.321588782360777e-06,
#   'Perimeter_mid_ZN_2': 7.321588782360777e-06,
#   'Perimeter_mid_ZN_3': 7.321588782360777e-06,
#   'Perimeter_top_ZN_2': 7.321588782360777e-06,
#   'Perimeter_mid_ZN_1': 7.321588782360777e-06,
#   'Perimeter_bot_ZN_4': 7.321588782360777e-06},
#  '../policy_library/119_3_1e1_blind.pth': {'Perimeter_top_ZN_3': 5.338736627891194e-06,
#   'Perimeter_bot_ZN_1': 5.338736627891194e-06,
#   'Perimeter_top_ZN_1': 5.338736627891194e-06,
#   'Core_bottom': 5.338736627891194e-06,
#   'Perimeter_top_ZN_4': 5.338736627891194e-06,
#   'Core_top': 5.338736627891194e-06,
#   'Perimeter_bot_ZN_2': 5.338736627891194e-06,
#   'Perimeter_bot_ZN_3': 5.338736627891194e-06,
#   'Perimeter_mid_ZN_4': 5.338736627891194e-06,
#   'Core_mid': 5.338736627891194e-06,
#   'Perimeter_mid_ZN_2': 5.338736627891194e-06,
#   'Perimeter_mid_ZN_3': 5.338736627891194e-06,
#   'Perimeter_top_ZN_2': 5.338736627891194e-06,
#   'Perimeter_mid_ZN_1': 5.338736627891194e-06,
#   'Perimeter_bot_ZN_4': 5.338736627891194e-06},
#  '../policy_library/119_3_blind.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/119_4.pth': {'Perimeter_top_ZN_3': 0.0,
#   'Perimeter_bot_ZN_1': 0.0,
#   'Perimeter_top_ZN_1': 0.0,
#   'Core_bottom': 0.0,
#   'Perimeter_top_ZN_4': 0.0,
#   'Core_top': 0.0,
#   'Perimeter_bot_ZN_2': 0.0,
#   'Perimeter_bot_ZN_3': 0.0,
#   'Perimeter_mid_ZN_4': 0.0,
#   'Core_mid': 0.0,
#   'Perimeter_mid_ZN_2': 0.0,
#   'Perimeter_mid_ZN_3': 0.0,
#   'Perimeter_top_ZN_2': 0.0,
#   'Perimeter_mid_ZN_1': 0.0,
#   'Perimeter_bot_ZN_4': 0.0},
#  '../policy_library/119_4_1e0.pth': {'Perimeter_top_ZN_3': 9.817251900301471e-09,
#   'Perimeter_bot_ZN_1': 9.817251900301471e-09,
#   'Perimeter_top_ZN_1': 9.817251900301471e-09,
#   'Core_bottom': 9.817251900301471e-09,
#   'Perimeter_top_ZN_4': 9.817251900301471e-09,
#   'Core_top': 9.817251900301471e-09,
#   'Perimeter_bot_ZN_2': 9.817251900301471e-09,
#   'Perimeter_bot_ZN_3': 9.817251900301471e-09,
#   'Perimeter_mid_ZN_4': 9.817251900301471e-09,
#   'Core_mid': 9.817251900301471e-09,
#   'Perimeter_mid_ZN_2': 9.817251900301471e-09,
#   'Perimeter_mid_ZN_3': 9.817251900301471e-09,
#   'Perimeter_top_ZN_2': 9.817251900301471e-09,
#   'Perimeter_mid_ZN_1': 9.817251900301471e-09,
#   'Perimeter_bot_ZN_4': 9.817251900301471e-09},
#  '../policy_library/119_4_1e1_blind.pth': {'Perimeter_top_ZN_3': 8.24328161286303e-09,
#   'Perimeter_bot_ZN_1': 8.24328161286303e-09,
#   'Perimeter_top_ZN_1': 8.24328161286303e-09,
#   'Core_bottom': 8.24328161286303e-09,
#   'Perimeter_top_ZN_4': 8.24328161286303e-09,
#   'Core_top': 8.24328161286303e-09,
#   'Perimeter_bot_ZN_2': 8.24328161286303e-09,
#   'Perimeter_bot_ZN_3': 8.24328161286303e-09,
#   'Perimeter_mid_ZN_4': 8.24328161286303e-09,
#   'Core_mid': 8.24328161286303e-09,
#   'Perimeter_mid_ZN_2': 8.24328161286303e-09,
#   'Perimeter_mid_ZN_3': 8.24328161286303e-09,
#   'Perimeter_top_ZN_2': 8.24328161286303e-09,
#   'Perimeter_mid_ZN_1': 8.24328161286303e-09,
#   'Perimeter_bot_ZN_4': 8.24328161286303e-09},
#  '../policy_library/119_4_blind.pth': {'Perimeter_top_ZN_3': 1.2509201496868627e-07,
#   'Perimeter_bot_ZN_1': 1.2509201496868627e-07,
#   'Perimeter_top_ZN_1': 1.2509201496868627e-07,
#   'Core_bottom': 1.2509201496868627e-07,
#   'Perimeter_top_ZN_4': 1.2509201496868627e-07,
#   'Core_top': 1.2509201496868627e-07,
#   'Perimeter_bot_ZN_2': 1.2509201496868627e-07,
#   'Perimeter_bot_ZN_3': 1.2509201496868627e-07,
#   'Perimeter_mid_ZN_4': 1.2509201496868627e-07,
#   'Core_mid': 1.2509201496868627e-07,
#   'Perimeter_mid_ZN_2': 1.2509201496868627e-07,
#   'Perimeter_mid_ZN_3': 1.2509201496868627e-07,
#   'Perimeter_top_ZN_2': 1.2509201496868627e-07,
#   'Perimeter_mid_ZN_1': 1.2509201496868627e-07,
#   'Perimeter_bot_ZN_4': 1.2509201496868627e-07}}

# %%
with open("grad_norm_raw_scores_16_06_2022.pkl", "wb+") as f:
    pickle.dump(policy_scores, f)

# %% [markdown]
# ### 2. Synflow

# %%
from zero_cost_proxies.synflow import SynFlow
policy_scores_synflow = {}
for zone in zones:
    print(zone)
    ope_data = log_data[log_data["zone"] == zone].sort_values(by=["timestep"])
    ope_data = log_data[:ts_end]
    for policy in tqdm(policy_list):
        agent = PPO(6, 1, 0.003, 0.0005, 1, 10, 0.2,
                    has_continuous_action_space=True, action_std_init=0.2, 
                    device=torch.device('cpu'), diverse_policies=list(),
                    diverse_weight=0, diverse_increase=True)
        agent.load(policy)
        agent.policy_evaluation = True
        agent.policy_old.set_action_std(0.1)
        sf = SynFlow(agent)
        if policy not in invalid_policies:
            synflow = sf.get_synflow()
        else:
            continue
        if policy not in policy_scores_synflow:
            policy_scores_synflow[policy] = {}
        if zone not in policy_scores_synflow[policy]:
            policy_scores_synflow[policy][zone] = synflow
# Out:
# Perimeter_top_ZN_3
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_1
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_top_ZN_1
#   0%|          | 0/800 [00:00<?, ?it/s]
# Core_bottom
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_top_ZN_4
#   0%|          | 0/800 [00:00<?, ?it/s]
# Core_top
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_2
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_3
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_4
#   0%|          | 0/800 [00:00<?, ?it/s]
# Core_mid
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_2
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_3
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_top_ZN_2
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_1
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_4
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
eval_data_loc = "../data/1month_eval.csv"
df = pd.read_csv(eval_data_loc, header=None, names=["datetime","policy","zone","energy"])
spearman_corr_synflow = {}
for zone in zones:
    eval_df = df[df["zone"] == zone]

    # invalid_policies = list(set(policy_list) - set(policy_scores.keys()))
    for i_policy in invalid_policies:
        eval_df = eval_df[eval_df["policy"]!=i_policy[3:]]
    eval_df = eval_df.sort_values(by=["energy"])
    score_list = []
    for i, row in eval_df.iterrows():
        score_list.append(policy_scores_synflow[f"../{row['policy']}"][zone])

    eval_df["ope_scores"] = score_list
    correlation = spearmanr(eval_df["energy"].values, eval_df["ope_scores"].values)
    spearman_corr_synflow[zone] = correlation

# %%
spearman_corr_synflow
# Out:
# {'Perimeter_top_ZN_3': SpearmanrResult(correlation=-0.02399655788801756, pvalue=0.5709350401752371),
#  'Perimeter_bot_ZN_1': SpearmanrResult(correlation=-0.007958102162903363, pvalue=0.8510831000493045),
#  'Perimeter_top_ZN_1': SpearmanrResult(correlation=0.004610768076634543, pvalue=0.9133850920486921),
#  'Core_bottom': SpearmanrResult(correlation=0.0846908842595264, pvalue=0.04534104009312232),
#  'Perimeter_top_ZN_4': SpearmanrResult(correlation=0.01057283551657145, pvalue=0.8030336897038484),
#  'Core_top': SpearmanrResult(correlation=0.056829866807361164, pvalue=0.17968820761249374),
#  'Perimeter_bot_ZN_2': SpearmanrResult(correlation=-0.005958563816778369, pvalue=0.8882133629244287),
#  'Perimeter_bot_ZN_3': SpearmanrResult(correlation=0.0023340313100253082, pvalue=0.9560902859952176),
#  'Perimeter_mid_ZN_4': SpearmanrResult(correlation=-0.03969206587361125, pvalue=0.34890507616128863),
#  'Core_mid': SpearmanrResult(correlation=0.06361473610160781, pvalue=0.13304293548202217),
#  'Perimeter_mid_ZN_2': SpearmanrResult(correlation=0.0006338122992286532, pvalue=0.9880706368819356),
#  'Perimeter_mid_ZN_3': SpearmanrResult(correlation=-0.03709011043969783, pvalue=0.3814289588292362),
#  'Perimeter_top_ZN_2': SpearmanrResult(correlation=-0.008439884696448836, pvalue=0.8421824912597491),
#  'Perimeter_mid_ZN_1': SpearmanrResult(correlation=-0.043382548933936775, pvalue=0.30588838397122997),
#  'Perimeter_bot_ZN_4': SpearmanrResult(correlation=0.03709162180655053, pvalue=0.38140954417207706)}

# %%
with open("data/synflow_spearman_corr15_06_2022.pkl", "wb+") as f:
    pickle.dump(spearman_corr_synflow, f)

# %% [markdown]
# ### 3. Jacobian Covariance

# %%
from zero_cost_proxies.jacob_cov import JacobianCovariance
policy_scores_jc = {}
for zone in zones:
    print(zone)
    ope_data = log_data[log_data["zone"] == zone].sort_values(by=["timestep"])
    ope_data = log_data[:ts_end]
    states = []
    for i, row in ope_data.iterrows():
        state_vars = ["outdoor_temp", "solar_irradiation", "time_hour",
                      "zone_humidity", "zone_temp", "zone_occupancy"]
        state = [row[var] for var in state_vars]
        states.append(state)
    states = torch.Tensor(states)
    for policy in tqdm(policy_list):
        agent = PPO(6, 1, 0.003, 0.0005, 1, 10, 0.2,
                    has_continuous_action_space=True, action_std_init=0.2, 
                    device=torch.device('cpu'), diverse_policies=list(),
                    diverse_weight=0, diverse_increase=True)
        agent.load(policy)
        agent.policy_evaluation = True
        agent.policy_old.set_action_std(0.1)
        jc = JacobianCovariance(agent)
        if policy not in invalid_policies:
            synflow = jc.compute_jacob_cov(states)
        else:
            continue
        if policy not in policy_scores_jc:
            policy_scores_jc[policy] = {}
        if zone not in policy_scores_jc[policy]:
            policy_scores_jc[policy][zone] = synflow
# Out:
# Perimeter_top_ZN_3
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_1
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_top_ZN_1
#   0%|          | 0/800 [00:00<?, ?it/s]
# Core_bottom
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_top_ZN_4
#   0%|          | 0/800 [00:00<?, ?it/s]
# Core_top
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_2
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_3
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_4
#   0%|          | 0/800 [00:00<?, ?it/s]
# Core_mid
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_2
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_3
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_top_ZN_2
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_mid_ZN_1
#   0%|          | 0/800 [00:00<?, ?it/s]
# Perimeter_bot_ZN_4
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
eval_data_loc = "../data/1month_eval.csv"
df = pd.read_csv(eval_data_loc, header=None, names=["datetime","policy","zone","energy"])
spearman_corr_jc = {}
for zone in zones:
    eval_df = df[df["zone"] == zone]

    # invalid_policies = list(set(policy_list) - set(policy_scores.keys()))
    for i_policy in invalid_policies:
        eval_df = eval_df[eval_df["policy"]!=i_policy[3:]]
    eval_df = eval_df.sort_values(by=["energy"])
    score_list = []
    for i, row in eval_df.iterrows():
        score_list.append(policy_scores_jc[f"../{row['policy']}"][zone])

    eval_df["ope_scores"] = score_list
    correlation = spearmanr(eval_df["energy"].values, eval_df["ope_scores"].values)
    spearman_corr_jc[zone] = correlation

# %%
spearman_corr_jc
# Out:
# {'Perimeter_top_ZN_3': SpearmanrResult(correlation=-0.010449571127394685, pvalue=0.8051123996789393),
#  'Perimeter_bot_ZN_1': SpearmanrResult(correlation=0.04045049723969454, pvalue=0.33976566455830204),
#  'Perimeter_top_ZN_1': SpearmanrResult(correlation=0.0025946733936231306, pvalue=0.9511926704797761),
#  'Core_bottom': SpearmanrResult(correlation=0.005884850333462486, pvalue=0.8895873841026646),
#  'Perimeter_top_ZN_4': SpearmanrResult(correlation=0.0204017350491469, pvalue=0.6302803636181593),
#  'Core_top': SpearmanrResult(correlation=0.005199273808824353, pvalue=0.9023818561397574),
#  'Perimeter_bot_ZN_2': SpearmanrResult(correlation=0.0006065389973867092, pvalue=0.9885839284050955),
#  'Perimeter_bot_ZN_3': SpearmanrResult(correlation=-0.017793115861382925, pvalue=0.6746480699322992),
#  'Perimeter_mid_ZN_4': SpearmanrResult(correlation=-0.018052040792685135, pvalue=0.6701901979459284),
#  'Core_mid': SpearmanrResult(correlation=-0.015886595275192424, pvalue=0.7078147788801797),
#  'Perimeter_mid_ZN_2': SpearmanrResult(correlation=-0.003340052045978527, pvalue=0.9371973467819701),
#  'Perimeter_mid_ZN_3': SpearmanrResult(correlation=-0.0634076101442943, pvalue=0.13431292505528686),
#  'Perimeter_top_ZN_2': SpearmanrResult(correlation=0.010076592123247022, pvalue=0.8121018128866129),
#  'Perimeter_mid_ZN_1': SpearmanrResult(correlation=-0.011586069594321655, pvalue=0.7846014521142544),
#  'Perimeter_bot_ZN_4': SpearmanrResult(correlation=-0.027134668748482946, pvalue=0.5220219760275169)}

# %% [markdown]
# ## 4. SNIP

# %%
from zero_cost_proxies.snip import SNIP
policy_scores_snip = {}
for zone in zones:
    print(zone)
    ope_data = log_data[log_data["zone"] == zone].sort_values(by=["timestep"])
    ope_data = log_data[:ts_end]
    for policy in tqdm(policy_list):
        agent = PPO(6, 1, 0.003, 0.0005, 1, 10, 0.2,
                    has_continuous_action_space=True, action_std_init=0.2, 
                    device=torch.device('cpu'), diverse_policies=list(),
                    diverse_weight=0, diverse_increase=True)
        agent.load(policy)
        agent.policy_evaluation = True
        agent.policy_old.set_action_std(0.1)
        snip = SNIP(agent, behavior_model)
        if policy not in invalid_policies:
            sn = snip.compute_snip(ope_data)
        else:
            continue
        if policy not in policy_scores_snip:
            policy_scores_snip[policy] = {}
        if zone not in policy_scores_snip[policy]:
            policy_scores_snip[policy][zone] = sn
# Out:
# Perimeter_top_ZN_3
#   0%|          | 0/870 [00:00<?, ?it/s]
# /Users/aakashsasikumar/Documents/MSc/Research/Dissimilar Policy/building-MARL/studies/../ope/iw.py:61: RuntimeWarning: divide by zero encountered in log
#   return np.log(value / (1- value))
# Perimeter_bot_ZN_1
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_top_ZN_1
#   0%|          | 0/870 [00:00<?, ?it/s]
# Core_bottom
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_top_ZN_4
#   0%|          | 0/870 [00:00<?, ?it/s]
# Core_top
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_bot_ZN_2
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_bot_ZN_3
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_mid_ZN_4
#   0%|          | 0/870 [00:00<?, ?it/s]
# Core_mid
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_mid_ZN_2
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_mid_ZN_3
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_top_ZN_2
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_mid_ZN_1
#   0%|          | 0/870 [00:00<?, ?it/s]
# Perimeter_bot_ZN_4
#   0%|          | 0/870 [00:00<?, ?it/s]

# %%
eval_data_loc = "../data/evaluation_report_20220820.csv"
df = pd.read_csv(eval_data_loc, header=None, names=["datetime","policy","zone","energy"])
spearman_corr_snip = {}
for zone in zones:
    eval_df = df[df["zone"] == zone]

    # invalid_policies = list(set(policy_list) - set(policy_scores.keys()))
    for i_policy in invalid_policies:
        eval_df = eval_df[eval_df["policy"]!=i_policy[3:]]
    eval_df = eval_df.sort_values(by=["energy"])
    score_list = []
    for i, row in eval_df.iterrows():
        score_list.append(policy_scores_snip[f"../{row['policy']}"][zone])

    eval_df["ope_scores"] = score_list
    correlation = spearmanr(eval_df["energy"].values, eval_df["ope_scores"].values)
    spearman_corr_snip[zone] = correlation

# %%
with open(f"data/15zone/snip/raw_scores/snip_raw_scores_{num_days}_days_06_09_2022.pkl", "wb+") as f:
    pickle.dump(policy_scores_snip, f)

# %%
with open(f"data/15zone/snip/spearman_corr/snip_spearman_corr_{num_days}_days_06_09_2022.pkl", "wb+") as f:
    pickle.dump(spearman_corr_snip, f)

# %%
spearman_corr_snip
# Out:
# {'Perimeter_top_ZN_3': SpearmanrResult(correlation=-0.703609201947425, pvalue=6.145721202954794e-131),
#  'Perimeter_bot_ZN_1': SpearmanrResult(correlation=-0.6542677284841102, pvalue=2.014542520570895e-107),
#  'Perimeter_top_ZN_1': SpearmanrResult(correlation=-0.6429933630539366, pvalue=1.1778615675130288e-102),
#  'Core_bottom': SpearmanrResult(correlation=-0.6380135679971297, pvalue=1.2979226034588598e-100),
#  'Perimeter_top_ZN_4': SpearmanrResult(correlation=-0.6492125052286722, pvalue=2.9287281926295602e-105),
#  'Core_top': SpearmanrResult(correlation=-0.6465556174660639, pvalue=3.861597881400266e-104),
#  'Perimeter_bot_ZN_2': SpearmanrResult(correlation=-0.6470613817535088, pvalue=2.3681563094549035e-104),
#  'Perimeter_bot_ZN_3': SpearmanrResult(correlation=-0.738009865860827, pvalue=1.9160657493383974e-150),
#  'Perimeter_mid_ZN_4': SpearmanrResult(correlation=-0.6484877425942756, pvalue=5.933859276103886e-105),
#  'Core_mid': SpearmanrResult(correlation=-0.6391503963141589, pvalue=4.4707228263724674e-101),
#  'Perimeter_mid_ZN_2': SpearmanrResult(correlation=-0.6477421712363973, pvalue=1.2244085637957353e-104),
#  'Perimeter_mid_ZN_3': SpearmanrResult(correlation=-0.753613888415918, pvalue=2.419992899936724e-160),
#  'Perimeter_top_ZN_2': SpearmanrResult(correlation=-0.6495396742413043, pvalue=2.12801022662324e-105),
#  'Perimeter_mid_ZN_1': SpearmanrResult(correlation=-0.6397130901281096, pvalue=2.6335821026477942e-101),
#  'Perimeter_bot_ZN_4': SpearmanrResult(correlation=-0.648282476726532, pvalue=7.244961891715504e-105)}
